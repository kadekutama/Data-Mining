# %% [markdown]
# # Scraping Kompas.com
#
# Pada python notebook ini akan dijelaskan mengenai scraping artikel dalam kompas.com
#
# Scraping dimulai dari halaman awal, lalu akan menelusuri setiap link, dan akan mengambil artikel beserta properties lainnya.
#
#
# ### Inisialisasi Url Lib
#
# urllib merupakan modul python untuk mengakses halaman web. Digunakan fungsi urlopen dan read untuk membaca kode HTML. Dapat dilihat r merupakan string HTML.

# %%
import urllib

r = urllib.urlopen('http://tekno.kompas.com/').read()
print(type(r))
print(r[1:1000])
# Out:
# <type 'str'>
# !-- 52.152 -->
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <script type="text/javascript">
#     var base_url = 'http://tekno.kompas.com/';
#     var crn_url  = 'aHR0cDovL3Rla25vLmtvbXBhcy5jb20v';
#     var limit_personalisasi = 5;
# </script>
#
# <!-- Meta, title, favicons, etc. -->
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <meta name="viewport" content="width=device-width">
# <meta name="description" content="Kompas Tekno">
# <meta name="keywords" content="artikel komputer, artikel teknologi, belajar komputer, berita indonesia, berita teknologi, berita terbaru, broadband internet, camera review, camera reviews, computer, computer building tips, computer buying tips, computer help, computer help desk, computer maintenance tips, computer parts, computer performance tips, computer repair, computer repair tips, computer safety tips, computer science, computer security tips, computer tech tips, computer tip of the day, computer tips, computer tips and tricks, com

# %% [markdown]
# ### Inisialisasi BeautifulSoup
#
# Untuk membantu dalam proses web scraping digunakan modul beautifulsoup.
#
# Pertama tama diimport dahulu modulnya, lalu string r diubah menjadi objek beautiful soup dan digunakan parser lxml
#
# Jika di print soup nya, sekilas terlihat seperti string HTML, namun sebenarnya itu merupakan sebuah objek soup yang bisa ditelusri setiap elemennya!

# %%
from bs4 import BeautifulSoup 

soup = BeautifulSoup(r,"lxml")
print(type(soup))
print(soup.prettify()[1:1000])
# Out:
# <class 'bs4.BeautifulSoup'>
# !-- 52.152 -->
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script type="text/javascript">
#    var base_url = 'http://tekno.kompas.com/';
#     var crn_url  = 'aHR0cDovL3Rla25vLmtvbXBhcy5jb20v';
#     var limit_personalisasi = 5;
#   </script>
#   <!-- Meta, title, favicons, etc. -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="Kompas Tekno" name="description"/>
#   <meta content="artikel komputer, artikel teknologi, belajar komputer, berita indonesia, berita teknologi, berita terbaru, broadband internet, camera review, camera reviews, computer, computer building tips, computer buying tips, computer help, computer help desk, computer maintenance tips, computer parts, computer performance tips, computer repair, computer repair tips, computer safety tips, computer science, computer security tips, computer tech tips, computer tip of the day, computer tips, computer tips and tricks,

# %% [markdown]
# ### Dapatkan Semua Link
#
# Untuk mendapatkan semua link kita dapat mencari semua tag html "a". Namun tentunya tidak semua hasilnya merupakan link artikel. perlu kita filter terlebih dahulu.

# %%
links = soup.find_all('a')
print(len(links))

for link in links:
    print('%s: %s'%(link.text.strip(),link["href"]))
# Out:
# 189
# : http://ads6.kompasads.com/new/www/delivery/ck.php?n=a4767a1d&cb=INSERT_RANDOM_NUMBER_HERE
# Kompas.com: http://www.kompas.com
# Kompasiana.com: http://www.kompasiana.com
# KompasKarier.com: http://www.kompaskarier.com
# Gramedia.com: http://www.gramedia.com
# Otomania.com: http://www.otomania.com
# Juara.net: http://www.juara.net
# Harian Kompas: http://print.kompas.com/
# Kompas TV: http://www.kompas.tv/
# : http://www.kompas.com
# Tekno: http://tekno.kompas.com/
# Register: https://sso.kompas.com/register/a29tcGFz
# Login: https://sso.kompas.com/login/a29tcGFz/aHR0cDovL3Rla25vLmtvbXBhcy5jb20v
# News: http://news.kompas.com
# Nasional: http://nasional.kompas.com
# Regional: http://regional.kompas.com
# Megapolitan: http://megapolitan.kompas.com
# Internasional: http://internasional.kompas.com
# Olahraga: http://olahraga.kompas.com
# Sains: http://sains.kompas.com
# Surat Pembaca: http://inside.kompas.com/suratpembaca
# Ekonomi: http://bisniskeuangan.kompas.com
# Makro: http://bisniskeuangan.kompas.com/makro
# Bisnis: http://bisniskeuangan.kompas.com/bisnis
# Keuangan: http://bisniskeuangan.kompas.com/keuangan
# Inspirasi: http://bisniskeuangan.kompas.com/inspirasi
# Bola: http://bola.kompas.com
# Indonesia: http://bola.kompas.com/ligaindonesia
# Inggris: http://bola.kompas.com/ligainggris
# Italia: http://bola.kompas.com/ligaitalia
# Spanyol: http://bola.kompas.com/ligaspanyol
# Champions: http://bola.kompas.com/ligachampions
# Internasional: http://bola.kompas.com/internasional
# Liga Lain: http://bola.kompas.com/ligalain
# Corner: http://bola.kompas.com/corner
# Foto: http://bola.kompas.com/foto
# livescore: http://bola.kompas.com/livescore
# Tekno: http://tekno.kompas.com
# APPS & OS: http://tekno.kompas.com/apps
# Gadget: http://tekno.kompas.com/gadget
# Internet: http://tekno.kompas.com/internet
# Hardware: http://tekno.kompas.com/hardware
# Business: http://tekno.kompas.com/business
# Gallery: http://tekno.kompas.com/gallery
# Entertainment: http://entertainment.kompas.com
# Gossips: http://entertainment.kompas.com/gossips
# Scenes: http://entertainment.kompas.com/scenes
# Music: http://entertainment.kompas.com/music
# Events: http://entertainment.kompas.com/events
# Gallery: http://entertainment.kompas.com/gallery
# Otomotif: http://otomotif.kompas.com
# News: http://otomotif.kompas.com/news
# Mobil: http://otomotif.kompas.com/produkmobil
# Motor: http://otomotif.kompas.com/produkmotor
# Sport: http://otomotif.kompas.com/sport
# Features: http://otomotif.kompas.com/feature
# Komunitas: http://otomotif.kompas.com/komunitas
# Galeri: http://otomotif.kompas.com/galeri
# Manufaktur: #
# Health: http://health.kompas.com
# Hot Topics: http://health.kompas.com/hottopics
# Health & Concerns: http://health.kompas.com/healthconcerns
# Nutrition: http://health.kompas.com/nutrition
# Sex: http://health.kompas.com/sex
# Fitness: http://health.kompas.com/fitness
# Psychology: http://health.kompas.com/phsychology
# Konsultasi: http://health.kompas.com/konsultasi
# Female: http://female.kompas.com
# Beauty: http://female.kompas.com/beauty
# Fashion: http://female.kompas.com/fashion
# Career: http://female.kompas.com/career
# Relationship: http://female.kompas.com/relationship
# Femalehood: http://female.kompas.com/femalehood
# Parentopedia: http://female.kompas.com/parentopedia
# Properti: http://properti.kompas.com
# News: http://properti.kompas.com/umum
# Hunian: http://properti.kompas.com/hunian
# Arsitektur: http://properti.kompas.com/arsitektur
# Beranda: http://properti.kompas.com/beranda
# Konsultasi: http://properti.kompas.com/konsultasi
# Figur: http://properti.kompas.com/figur
# Tips: http://properti.kompas.com/tips
# Galeri 360: http://properti.kompas.com/galleri360
# Travel: http://travel.kompas.com
# News: http://travel.kompas.com/news
# Travel Story: http://travel.kompas.com/travel-story
# Food Story: http://travel.kompas.com/food-story
# Travel Tips: http://travel.kompas.com/travel-tips
# Hotel Story: http://travel.kompas.com/hotel-story
# Gallery: http://travel.kompas.com/gallery
# Edukasi: http://edukasi.kompas.com
# Kolom: http://kolom.kompas.com
# Foto: http://foto.kompas.com
# Today's Photo: http://foto.kompas.com/photo
# Photo Motion: http://foto.kompas.com/video
# Video: http://video.kompas.com
# Tekno: http://video.kompas.com/rubrik/tekno
# News: http://video.kompas.com/rubrik/news
# Entertainment: http://video.kompas.com/rubrik/entertainment
# Lifestyle: http://video.kompas.com/rubrik/lifestyle
# Inspirasi: http://video.kompas.com/rubrik/inspirasi
# Travel: http://video.kompas.com/rubrik/travel
# Animations: http://video.kompas.com/rubrik/animations
# TV: http://tv.kompas.com/
# LIVE: http://tv.kompas.com/live
# Peristiwa: http://tv.kompas.com/rubrik/peristiwa
# Sports: http://tv.kompas.com/rubrik/sports
# Entertainment: http://tv.kompas.com/rubrik/entertainment
# Feature: http://tv.kompas.com/rubrik/feature
# Aiman: http://tv.kompas.com/rubrik/aiman
# Mencari Pemimpin: http://tv.kompas.com/rubrik/mencari.pemimpin
# Rosi: http://tv.kompas.com/rubrik/rosi
# Satu Meja: http://tv.kompas.com/rubrik/satu.meja
# Ultimate U: http://tv.kompas.com/rubrik/ultimate.u
# VIK: http://vik.kompas.com
# #Review: http://tekno.kompas.com/tag/Review
# #Android: http://tekno.kompas.com/tag/Android
# #Apple: http://tekno.kompas.com/tag/Apple
# #Menkominfo: http://tekno.kompas.com/tag/Menkominfo
# #Smartfren: http://tekno.kompas.com/tag/Smartfren
# #Samsung: http://tekno.kompas.com/tag/Samsung
# #Balon Google: http://tekno.kompas.com/tag/Balon Google
# #iPhone 7: http://tekno.kompas.com/tag/iPhone 7
# #Facebook: http://tekno.kompas.com/tag/Facebook
# #Lenovo: http://tekno.kompas.com/tag/Lenovo
# #Xiaomi: http://tekno.kompas.com/tag/Xiaomi
# Google Hapus Utang "Rp 1,4 Miliar" Bocah 12 Tahun: http://tekno.kompas.com/read/2016/10/10/15160067/google.hapus.utang.rp.1.4.miliar.bocah.12.tahun.
# Uber Berhentikan Sopir "Khrisna Murti Berwajah Kaka Slank": http://tekno.kompas.com/read/2016/10/08/15160097/uber.berhentikan.sopir.khrisna.murti.berwajah.kaka.slank.
# Lagi, Ponsel Selamatkan Nyawa Manusia: http://tekno.kompas.com/read/2016/10/09/12570077/lagi.ponsel.selamatkan.nyawa.manusia
# Cerita Mahasiswa Asal Boyolali Magang di Silicon Valley: http://tekno.kompas.com/read/2016/10/07/15550027/cerita.mahasiswa.asal.boyolali.magang.di.silicon.valley
# : http://ads3.kompasads.com/new/www/delivery/ck.php?n=a33e13b3&cb=INSERT_RANDOM_NUMBER_HERE
# SOFTWARE
#
#
#
# Kisah Anak Pinggiran Belajar dan Akhirnya Jadi Guru "Coding"
# 10 Oktober 2016 | 14:37 WIB: http://tekno.kompas.com/read/2016/10/10/14374227/kisah.anak.pinggiran.belajar.dan.akhirnya.jadi.guru.coding.
# HARDWARE
#
#
#
# Epson Luncurkan Proyektor Rp 1 Miliar di Yogyakarta
# 10 Oktober 2016 | 14:00 WIB: http://tekno.kompas.com/read/2016/10/10/14002657/epson.luncurkan.proyektor.rp.1.miliar.di.yogyakarta
# SOFTWARE
#
#
#
# Pokemon Go Makin Seru dan Mudah Dimainkan
# 10 Oktober 2016 | 12:28 WIB: http://tekno.kompas.com/read/2016/10/10/12280017/pokemon.go.makin.seru.dan.mudah.dimainkan
# LIPSUS
#
#
#
# Duo Pixel Buatan Google: http://tekno.kompas.com/lipsus/4363/1/Duo.Pixel.Buatan.Google
# Ponsel Google Pixel Varian "Really Blue" Ludes: http://tekno.kompas.com/lipsus/4363/1/Duo.Pixel.Buatan.Google
# Ada Campur Tangan HTC di Balik Duo Google Pixel: http://tekno.kompas.com/lipsus/4363/1/Duo.Pixel.Buatan.Google
# Google Luncurkan Android Pixel, Bagaimana Nasib Nexus?: http://tekno.kompas.com/lipsus/4363/1/Duo.Pixel.Buatan.Google
# E-BUSINESS
#
#
#
# Kemenangan "Rp 1,5 Triliun" Apple atas Samsung Dikembalikan
# 10 Oktober 2016 | 11:35 WIB: http://tekno.kompas.com/read/2016/10/10/11350037/kemenangan.rp.1.5.triliun.apple.atas.samsung.dikembalikan
# GADGET
#
#
#
# Bocoran Wujud Xiaomi Mi6 Beredar di Internet
# 10 Oktober 2016 | 10:59 WIB: http://tekno.kompas.com/read/2016/10/10/10591277/bocoran.wujud.xiaomi.mi6.beredar.di.internet
# GADGET
#
#
#
# Lima Galaxy Note 7 Versi "Aman" Terbakar di Amerika
# 10 Oktober 2016 | 10:01 WIB: http://tekno.kompas.com/read/2016/10/10/10010237/lima.galaxy.note.7.versi.aman.terbakar.di.amerika
# GADGET
#
#
#
# Samsung Dikabarkan Hentikan Sementara Produksi Galaxy Note 7
# 10 Oktober 2016 | 09:19 WIB: http://tekno.kompas.com/read/2016/10/10/09191217/samsung.dikabarkan.hentikan.sementara.produksi.galaxy.note.7
# SOFTWARE
#
#
#
# Google Duo Gantikan Hangouts Jadi Aplikasi Bawaan di Android
# 10 Oktober 2016 | 08:41 WIB: http://tekno.kompas.com/read/2016/10/10/08410067/google.duo.gantikan.hangouts.jadi.aplikasi.bawaan.di.android
# GADGET
#
#
#
# "Smartphone" Jangan Keseringan Pakai "Powerbank"
# 10 Oktober 2016 | 07:25 WIB: http://tekno.kompas.com/read/2016/10/10/07252037/.smartphone.jangan.keseringan.pakai.powerbank.
# SOFTWARE
#
#
#
# Prisma di Android Sudah Bisa Olah Foto secara "Offline"
# 10 Oktober 2016 | 06:53 WIB: http://tekno.kompas.com/read/2016/10/10/06532997/prisma.di.android.sudah.bisa.olah.foto.secara.offline.
# GADGET
#
#
#
# iPhone 7 Dipermak dengan Mesin Gerinda Listrik
# 9 Oktober 2016 | 16:14 WIB: http://tekno.kompas.com/read/2016/10/09/16143347/iphone.7.dipermak.dengan.mesin.gerinda.listrik
# GADGET
#
#
#
# Lagi, Ponsel Selamatkan Nyawa Manusia
# 9 Oktober 2016 | 12:57 WIB: http://tekno.kompas.com/read/2016/10/09/12570077/lagi.ponsel.selamatkan.nyawa.manusia
# SOFTWARE
#
#
#
# Facebook Bikin Aplikasi Buat yang Ogah Diam di Rumah
# 9 Oktober 2016 | 11:05 WIB: http://tekno.kompas.com/read/2016/10/09/11050057/facebook.bikin.aplikasi.buat.yang.ogah.diam.di.rumah
# SOFTWARE
#
#
#
# Para Bocah Bermain Game untuk Membuat Game
# 9 Oktober 2016 | 10:08 WIB: http://tekno.kompas.com/read/2016/10/09/10080037/para.bocah.bermain.game.untuk.membuat.game
# GADGET
#
#
#
# Ponsel Google Pixel Varian "Really Blue" Ludes
# 9 Oktober 2016 | 08:52 WIB: http://tekno.kompas.com/read/2016/10/09/08522147/ponsel.google.pixel.varian.really.blue.ludes
# INTERNET
#
#
#
# Onno Purbo: Internet di Indonesia Jauh dari Cukup
# 8 Oktober 2016 | 20:21 WIB: http://tekno.kompas.com/read/2016/10/08/20210207/onno.purbo.internet.di.indonesia.jauh.dari.cukup
# INTERNET
#
#
#
# Uber Berhentikan Sopir "Khrisna Murti Berwajah Kaka Slank"
# 8 Oktober 2016 | 15:16 WIB: http://tekno.kompas.com/read/2016/10/08/15160097/uber.berhentikan.sopir.khrisna.murti.berwajah.kaka.slank.
# INDEKS: http://tekno.kompas.com/index
# : http://ads3.kompasads.com/new/www/delivery/ck.php?n=a33e13b3&cb=INSERT_RANDOM_NUMBER_HERE
# REVIEW: http://tekno.kompas.com/lipsus/3808/1/review.gadget
# Melihat dari Dekat Samsung Gear 360 di Jakarta: http://tekno.kompas.com/read/2016/10/06/18270007/melihat.dari.dekat.samsung.gear.360.di.jakarta
# Kesan Pertama Menggenggam Android "Tahan Lama" LG X Power: http://tekno.kompas.com/read/2016/10/05/20050067/kesan.pertama.menggenggam.android.tahan.lama.lg.x.power
# Menjajal Mirrorless “Sensor Besar” Fujifilm GFX 50S: http://tekno.kompas.com/read/2016/09/28/14280057/menjajal.mirrorless.sensor.besar.fujifilm.gfx.50s
# GALERI: http://tekno.kompas.com/gallery
# Android Baru Buatan Google: Pixel dan Pixel XL: http://tekno.kompas.com/gallery/detail/15/1/android.baru.buatan.google.pixel.dan.pixel.xl
# Ramainya Pameran Fotografi Photokina 2016 di Jerman: http://tekno.kompas.com/gallery/detail/14/1/ramainya.pameran.fotografi.photokina.2016.di.jerman
# Presiden Jokowi di Pusat Komputer Mangga Dua: http://tekno.kompas.com/gallery/detail/13/1/presiden.jokowi.di.pusat.komputer.mangga.dua
# Menyelisik Alasan Google Ubah Foke Jadi Ahok di "Sungai Bersih Jakarta": http://tekno.kompas.com/read/2016/10/04/08180037/menyelisik.alasan.google.ubah.foke.jadi.ahok.di.sungai.bersih.jakarta.
# 3 Hal yang Ditanya Orang Jakarta Sebelum Beli "Smartphone": http://tekno.kompas.com/read/2016/10/07/09025767/3.hal.yang.ditanya.orang.jakarta.sebelum.beli.smartphone.
# Cerita Mahasiswa Asal Boyolali Magang di Silicon Valley: http://tekno.kompas.com/read/2016/10/07/15550027/cerita.mahasiswa.asal.boyolali.magang.di.silicon.valley
# Berapa Harga Smartphone Google Pixel dan Pixel XL?: http://tekno.kompas.com/read/2016/10/05/08524377/berapa.harga.smartphone.google.pixel.dan.pixel.xl.
# Xiaomi Redmi 3S Plus Resmi Dibanderol Rp 1,9 Juta: http://tekno.kompas.com/read/2016/10/03/19070017/xiaomi.redmi.3s.plus.resmi.dibanderol.rp.1.9.juta
# Samsung Z2 Sudah Muncul di Jakarta, Terbatas dan Lebih Mahal: http://tekno.kompas.com/read/2016/10/04/19080077/samsung.z2.sudah.muncul.di.jakarta.terbatas.dan.lebih.mahal
# Uber Berhentikan Sopir "Khrisna Murti Berwajah Kaka Slank": http://tekno.kompas.com/read/2016/10/08/15160097/uber.berhentikan.sopir.khrisna.murti.berwajah.kaka.slank.
# Ini Daftar Xiaomi yang Kebagian Android 7.0 "Nougat": http://tekno.kompas.com/read/2016/10/07/10510067/ini.daftar.xiaomi.yang.kebagian.android.7.0.nougat.
# Ayah Kandung Steve Jobs Menyesal Tak Mengenal Anaknya: http://tekno.kompas.com/read/2016/10/06/14054007/ayah.kandung.steve.jobs.menyesal.tak.mengenal.anaknya
# 8 Fitur Ini Bikin Pixel Berbeda dari Android Biasa: http://tekno.kompas.com/read/2016/10/05/11240097/8.fitur.ini.bikin.pixel.berbeda.dari.android.biasa
# Kabar Palmerah: http://lipsus.kompas.com/topikpilihanlist/3361/1/kabar.palmerah
# About Us: http://inside.kompas.com/about-us
# Advertise: http://apps.kompas.com/ratecard/
# Policy: http://inside.kompas.com/policy
# Pedoman Media Siber: http://inside.kompas.com/pedoman
# Career: http://inside.kompas.com/karir
# Forum: http://forum.kompas.com/
# Contact Us: http://inside.kompas.com/contact-us
# : http://www.facebook.com/kompascom
# : http://instagram.com/kompascom
# : http://www.twitter.com/kompascom
# : http://pinterest.com/kompascom/
# (Kompas Gramedia Digital Group): http://www.kompasgramedia.com
# Back to Top: #
# : http://ads4.kompasads.com/new2/www/delivery/ck.php?n=a29affdc&cb=INSERT_RANDOM_NUMBER_HERE
# : http://ads4.kompasads.com/new2/www/delivery/ck.php?n=a4bef7cd&cb=INSERT_RANDOM_NUMBER_HERE
# : http://ads3.kompasads.com/new/www/delivery/ck.php?n=a672f44a&cb=INSERT_RANDOM_NUMBER_HERE

# %% [markdown]
# Dapat dilihat link yang merujuk ke berita memiliki pola '/read/' dan benar-benar link bukan javascript maupun link '#'. Maka dari itu bisa kita filter, dan hasilnya bisa kita simpan di sebuah list

# %%
berita_link = [link for link in links if '/read/' in str(link) and 'javascript:void(0)' not in str(link) 
               and '#' not in str(link)]
print(len(berita_link))
for link in berita_link:
    print('%s: %s'%(link.text.strip(),link["href"]))
# Out:
# 34
# Google Hapus Utang "Rp 1,4 Miliar" Bocah 12 Tahun: http://tekno.kompas.com/read/2016/10/10/15160067/google.hapus.utang.rp.1.4.miliar.bocah.12.tahun.
# Uber Berhentikan Sopir "Khrisna Murti Berwajah Kaka Slank": http://tekno.kompas.com/read/2016/10/08/15160097/uber.berhentikan.sopir.khrisna.murti.berwajah.kaka.slank.
# Lagi, Ponsel Selamatkan Nyawa Manusia: http://tekno.kompas.com/read/2016/10/09/12570077/lagi.ponsel.selamatkan.nyawa.manusia
# Cerita Mahasiswa Asal Boyolali Magang di Silicon Valley: http://tekno.kompas.com/read/2016/10/07/15550027/cerita.mahasiswa.asal.boyolali.magang.di.silicon.valley
# SOFTWARE
#
#
#
# Kisah Anak Pinggiran Belajar dan Akhirnya Jadi Guru "Coding"
# 10 Oktober 2016 | 14:37 WIB: http://tekno.kompas.com/read/2016/10/10/14374227/kisah.anak.pinggiran.belajar.dan.akhirnya.jadi.guru.coding.
# HARDWARE
#
#
#
# Epson Luncurkan Proyektor Rp 1 Miliar di Yogyakarta
# 10 Oktober 2016 | 14:00 WIB: http://tekno.kompas.com/read/2016/10/10/14002657/epson.luncurkan.proyektor.rp.1.miliar.di.yogyakarta
# SOFTWARE
#
#
#
# Pokemon Go Makin Seru dan Mudah Dimainkan
# 10 Oktober 2016 | 12:28 WIB: http://tekno.kompas.com/read/2016/10/10/12280017/pokemon.go.makin.seru.dan.mudah.dimainkan
# E-BUSINESS
#
#
#
# Kemenangan "Rp 1,5 Triliun" Apple atas Samsung Dikembalikan
# 10 Oktober 2016 | 11:35 WIB: http://tekno.kompas.com/read/2016/10/10/11350037/kemenangan.rp.1.5.triliun.apple.atas.samsung.dikembalikan
# GADGET
#
#
#
# Bocoran Wujud Xiaomi Mi6 Beredar di Internet
# 10 Oktober 2016 | 10:59 WIB: http://tekno.kompas.com/read/2016/10/10/10591277/bocoran.wujud.xiaomi.mi6.beredar.di.internet
# GADGET
#
#
#
# Lima Galaxy Note 7 Versi "Aman" Terbakar di Amerika
# 10 Oktober 2016 | 10:01 WIB: http://tekno.kompas.com/read/2016/10/10/10010237/lima.galaxy.note.7.versi.aman.terbakar.di.amerika
# GADGET
#
#
#
# Samsung Dikabarkan Hentikan Sementara Produksi Galaxy Note 7
# 10 Oktober 2016 | 09:19 WIB: http://tekno.kompas.com/read/2016/10/10/09191217/samsung.dikabarkan.hentikan.sementara.produksi.galaxy.note.7
# SOFTWARE
#
#
#
# Google Duo Gantikan Hangouts Jadi Aplikasi Bawaan di Android
# 10 Oktober 2016 | 08:41 WIB: http://tekno.kompas.com/read/2016/10/10/08410067/google.duo.gantikan.hangouts.jadi.aplikasi.bawaan.di.android
# GADGET
#
#
#
# "Smartphone" Jangan Keseringan Pakai "Powerbank"
# 10 Oktober 2016 | 07:25 WIB: http://tekno.kompas.com/read/2016/10/10/07252037/.smartphone.jangan.keseringan.pakai.powerbank.
# SOFTWARE
#
#
#
# Prisma di Android Sudah Bisa Olah Foto secara "Offline"
# 10 Oktober 2016 | 06:53 WIB: http://tekno.kompas.com/read/2016/10/10/06532997/prisma.di.android.sudah.bisa.olah.foto.secara.offline.
# GADGET
#
#
#
# iPhone 7 Dipermak dengan Mesin Gerinda Listrik
# 9 Oktober 2016 | 16:14 WIB: http://tekno.kompas.com/read/2016/10/09/16143347/iphone.7.dipermak.dengan.mesin.gerinda.listrik
# GADGET
#
#
#
# Lagi, Ponsel Selamatkan Nyawa Manusia
# 9 Oktober 2016 | 12:57 WIB: http://tekno.kompas.com/read/2016/10/09/12570077/lagi.ponsel.selamatkan.nyawa.manusia
# SOFTWARE
#
#
#
# Facebook Bikin Aplikasi Buat yang Ogah Diam di Rumah
# 9 Oktober 2016 | 11:05 WIB: http://tekno.kompas.com/read/2016/10/09/11050057/facebook.bikin.aplikasi.buat.yang.ogah.diam.di.rumah
# SOFTWARE
#
#
#
# Para Bocah Bermain Game untuk Membuat Game
# 9 Oktober 2016 | 10:08 WIB: http://tekno.kompas.com/read/2016/10/09/10080037/para.bocah.bermain.game.untuk.membuat.game
# GADGET
#
#
#
# Ponsel Google Pixel Varian "Really Blue" Ludes
# 9 Oktober 2016 | 08:52 WIB: http://tekno.kompas.com/read/2016/10/09/08522147/ponsel.google.pixel.varian.really.blue.ludes
# INTERNET
#
#
#
# Onno Purbo: Internet di Indonesia Jauh dari Cukup
# 8 Oktober 2016 | 20:21 WIB: http://tekno.kompas.com/read/2016/10/08/20210207/onno.purbo.internet.di.indonesia.jauh.dari.cukup
# INTERNET
#
#
#
# Uber Berhentikan Sopir "Khrisna Murti Berwajah Kaka Slank"
# 8 Oktober 2016 | 15:16 WIB: http://tekno.kompas.com/read/2016/10/08/15160097/uber.berhentikan.sopir.khrisna.murti.berwajah.kaka.slank.
# Melihat dari Dekat Samsung Gear 360 di Jakarta: http://tekno.kompas.com/read/2016/10/06/18270007/melihat.dari.dekat.samsung.gear.360.di.jakarta
# Kesan Pertama Menggenggam Android "Tahan Lama" LG X Power: http://tekno.kompas.com/read/2016/10/05/20050067/kesan.pertama.menggenggam.android.tahan.lama.lg.x.power
# Menjajal Mirrorless “Sensor Besar” Fujifilm GFX 50S: http://tekno.kompas.com/read/2016/09/28/14280057/menjajal.mirrorless.sensor.besar.fujifilm.gfx.50s
# Menyelisik Alasan Google Ubah Foke Jadi Ahok di "Sungai Bersih Jakarta": http://tekno.kompas.com/read/2016/10/04/08180037/menyelisik.alasan.google.ubah.foke.jadi.ahok.di.sungai.bersih.jakarta.
# 3 Hal yang Ditanya Orang Jakarta Sebelum Beli "Smartphone": http://tekno.kompas.com/read/2016/10/07/09025767/3.hal.yang.ditanya.orang.jakarta.sebelum.beli.smartphone.
# Cerita Mahasiswa Asal Boyolali Magang di Silicon Valley: http://tekno.kompas.com/read/2016/10/07/15550027/cerita.mahasiswa.asal.boyolali.magang.di.silicon.valley
# Berapa Harga Smartphone Google Pixel dan Pixel XL?: http://tekno.kompas.com/read/2016/10/05/08524377/berapa.harga.smartphone.google.pixel.dan.pixel.xl.
# Xiaomi Redmi 3S Plus Resmi Dibanderol Rp 1,9 Juta: http://tekno.kompas.com/read/2016/10/03/19070017/xiaomi.redmi.3s.plus.resmi.dibanderol.rp.1.9.juta
# Samsung Z2 Sudah Muncul di Jakarta, Terbatas dan Lebih Mahal: http://tekno.kompas.com/read/2016/10/04/19080077/samsung.z2.sudah.muncul.di.jakarta.terbatas.dan.lebih.mahal
# Uber Berhentikan Sopir "Khrisna Murti Berwajah Kaka Slank": http://tekno.kompas.com/read/2016/10/08/15160097/uber.berhentikan.sopir.khrisna.murti.berwajah.kaka.slank.
# Ini Daftar Xiaomi yang Kebagian Android 7.0 "Nougat": http://tekno.kompas.com/read/2016/10/07/10510067/ini.daftar.xiaomi.yang.kebagian.android.7.0.nougat.
# Ayah Kandung Steve Jobs Menyesal Tak Mengenal Anaknya: http://tekno.kompas.com/read/2016/10/06/14054007/ayah.kandung.steve.jobs.menyesal.tak.mengenal.anaknya
# 8 Fitur Ini Bikin Pixel Berbeda dari Android Biasa: http://tekno.kompas.com/read/2016/10/05/11240097/8.fitur.ini.bikin.pixel.berbeda.dari.android.biasa

# %% [markdown]
# ### Dapatkan Isi Berita
#
# Sebelum kita menelusuri satu per satu kita perlu tahu dahulu struktur dari sebuah halaman berita pada kompas.com untuk mendapatkan properties yang kita inginkan.
#
# Gunakan inspect element!
#
# Misalkan disini ingin diambil judul berita, isi berita, beserta tanggal pembuatan berita. Setelah dianalisa, judul berada pada elemen div yang mempunyai class kcm-read-top, sedangkan isi_berita pada div yang mempunyai kelas kcm-read-text, dan tanggal div dengan class kcm-date. Untuk mendapatkan text atau inner html nya kita bisa memanfaatkan properti text.
#
# Namun disini terdapat kendala karena tag tanggal tergabung dengan berbagai text lainnya jadi harus dilakukan pemrosesan terlebih dahulu. Cara yang akan digunakan disini sedikit berbahaya karena memanfaatkan separator yang bisa jadi tidak konsisten di semua berita, meskipun sampai saat ini belum ditemukan.

# %%
html = urllib.urlopen("http://tekno.kompas.com/read/2016/04/26/19500067/6.Aplikasi.Gratis.Pengirit.Baterai.Android").read()
soup = BeautifulSoup(html, "lxml")

judul = soup.find("div","kcm-read-top").find("h2").text.strip()
isi_berita = soup.find("div","kcm-read-text").text.strip()
tanggal = soup.find("div","kcm-date").text

#print(tanggal.strip())
tanggal = tanggal.strip().split(',')[1].split('|')[0].strip()
print(tanggal)

# %% [markdown]
# Sebagai tambahan, python juga dapat menyimpan sebuah gambar. Disini akan coba kita terapkan untuk menyimpan gambar dari berita.

# %%
gambar = soup.find("div","kcm-read-top").find("img")
print(gambar['src'])

from PIL import Image
from StringIO import StringIO
import string

r = urllib.urlopen(gambar["src"]).read()
print(r)

i = Image.open(StringIO(r))
exclude = set(string.punctuation)
judul = ''.join(ch for ch in judul if ch not in exclude)

nama_file = "images/" + judul + ".jpg"
i.save(nama_file,'JPEG')

# %% [markdown]
# ### Gabungkan ke Dalam Fungsi

# %%
def getBerita(link):
    html = urllib.urlopen(link).read()
    soup = BeautifulSoup(html, "lxml")

    judul = soup.find("div","kcm-read-top").find("h2").text.strip().encode("utf8")
    isi_berita = soup.find("div","kcm-read-text").text.strip().encode("utf8")
    tanggal = soup.find("div","kcm-date").text
    tanggal = tanggal.strip().split(',')[1].split('|')[0].strip()
    gambar = soup.find("div","kcm-read-top").find("img")
    
    r = urllib.urlopen(gambar["src"]).read()
    i = Image.open(StringIO(r))
    
    exclude = set(string.punctuation)
    judul = ''.join(ch for ch in judul if ch not in exclude)
    
    nama_file = "images/" + judul + ".jpg"
    i.save(nama_file,'JPEG')
    
    return [judul,isi_berita,tanggal]

# %% [markdown]
# ### Dapatkan Semua Data dari Link Berita

# %%
berita = []
for link in berita_link:
    print('%s: %s'%(link.text.strip(),link["href"]))
    try:
        berita.append(getBerita(link["href"]))
    except:
        pass

# %% [markdown]
# ### Simpan ke dalam CSV

# %%
#print(berita)
import csv

with open('data_berita.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerows(berita)
